# %%
from pathlib import Path, PurePath
import json
import pickle

# %% [markdown]
# Test Speed of purepath vs concrete path (Path)

# %%
lots_of_paths = Path("file_list.txt").read_text().splitlines()

# %%
# %%timeit
for i in lots_of_paths:
    p = Path(i)
    p.name
# Out:
# 4.04 s ± 16.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
for i in lots_of_paths:
    p = PurePath(i)
    p.name
# Out:
# 3.93 s ± 45.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Loading Different Files

# %%
text_file = "file_list.txt"
json_file = "sample.json"
pickle_file = "sample.pickle"

# %%
with open(text_file) as f:
    result = f.read()

result = Path(text_file).read_text()

# %%
with open(json_file) as f:
    json.load(f)

json.loads(Path(json_file).read_text())
# Out:
# {'animals': ['cat', 'dog', 'rabbit', 'rat']}

# %%
with open(pickle_file, "rb") as f:
    pickle.load(f)

pickle.loads(Path(pickle_file).read_bytes())
# Out:
# 'thisisapythonobject'

# %% [markdown]
# .rglob()

# %%
list(Path.cwd().rglob("*"))
# Out:
# [WindowsPath('c:/Users/cforbes/Documents/Github/pathlib-os-boston-meetup/.git'),
#  WindowsPath('c:/Users/cforbes/Documents/Github/pathlib-os-boston-meetup/.gitignore'),
#  WindowsPath('c:/Users/cforbes/Documents/Github/pathlib-os-boston-meetup/.venv'),
#  WindowsPath('c:/Users/cforbes/Documents/Github/pathlib-os-boston-meetup/file_list.txt'),
#  WindowsPath('c:/Users/cforbes/Documents/Github/pathlib-os-boston-meetup/gen_file_paths.py'),
#  WindowsPath('c:/Users/cforbes/Documents/Github/pathlib-os-boston-meetup/notes.txt'),
#  WindowsPath('c:/Users/cforbes/Documents/Github/pathlib-os-boston-meetup/README.md'),
#  WindowsPath('c:/Users/cforbes/Documents/Github/pathlib-os-boston-meetup/requirements.txt'),
#  WindowsPath('c:/Users/cforbes/Documents/Github/pathlib-os-boston-meetup/sample.json'),
#  WindowsPath('c:/Users/cforbes/Documents/Github/pathlib-os-boston-meetup/sample.pickle'),
#  WindowsPath('c:/Users/cforbes/Documents/Github/pathlib-os-boston-meetup/sandbox.ipynb'),
# ...

# %%
Path.cwd().stat()
# Out:
# os.stat_result(st_mode=16895, st_ino=2533274791455205, st_dev=2154604732, st_nlink=1, st_uid=0, st_gid=0, st_size=4096, st_atime=1683681097, st_mtime=1683679739, st_ctime=1683676947)
